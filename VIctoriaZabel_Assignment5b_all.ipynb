# %% [markdown]
# <a href="https://colab.research.google.com/github/victoriaazabel/SEdigitalorganizations/blob/main/VIctoriaZabel_Assignment5b_all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test: Homework 5 but all in one

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
from google.colab import data_table
from sklearn.model_selection import train_test_split
import glob
import os
data_table.enable_dataframe_formatter()

"""
#import the three datasets for agriculture
drive.mount('/content/drive')
directory = '/content/drive/My Drive/'
  
# merging the files
joined_files = os.path.join('/content/drive/MyDrive/', "*.csv")
  
# A list of all joined files is returned
joined_list = glob.glob(joined_files)
  
# Finally, the files are joined
all_data_1 = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)
"""
#only gives me medi??
# Out:
# '\n#import the three datasets for agriculture\ndrive.mount(\'/content/drive\')\ndirectory = \'/content/drive/My Drive/\'\n  \n# merging the files\njoined_files = os.path.join(\'/content/drive/MyDrive/\', "*.csv")\n  \n# A list of all joined files is returned\njoined_list = glob.glob(joined_files)\n  \n# Finally, the files are joined\nall_data_1 = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)\n'

# %%
#all_data_1
# Out:
# Warning: total number of rows (148594) exceeds max_rows (20000). Falling back to pandas display.
#                                                   Authors  \
# 0                                   Qi X.-L., Zhang S.-C.
# 1       Joannopoulos J.D., Johnson S.G., Winn J.N., Me...
# 2       Beringer J., Arguin J.-F., Barnett R.M., Copic...
# 3       Chatrchyan S., Khachatryan V., Sirunyan A.M., ...
# 4       Aad G., Abajyan T., Abbott B., Abdallah J., Ab...
# ...                                                   ...
# 148589               Krieger J.N., Nyberg L., Nickel J.C.
# 148590                          Meltzer H.Y., McGurk S.R.
# 148591  Carani C., Qin K., Simoni M., Faustini-Fustini...
# 148592       Tiedge M., Lortz S., Drinkgern J., Lenzen S.
# 148593  The Cardiac Arrhythmia Suppression Trial II In...
#
#                                              Author(s) ID  \
# 0                                 8250038200;57202874643;
# 1          36046746000;7406327642;35514528300;7101840938;
# 2       57203234311;57202562334;56438869500;1584495540...
# 3       6508029813;6701387290;16239550900;35222495600;...
# 4       26326745400;55336496600;35226946900;1623222600...
# ...                                                   ...
# 148589                  7201508311;7102383649;7102059906;
# 148590                            35351230800;7003914169;
# 148591  56216566200;7006784508;7005805305;6602864074;6...
# 148592       7003653970;6603122305;6506246040;7005352936;
# 148593                                                NaN
#
#                                                     Title  Year  \
# 0              Topological insulators and superconductors  2011
# 1            Photonic crystals: Molding the flow of light  2011
# 2                              Review of particle physics  2012
# 3       Observation of a new boson at a mass of 125 Ge...  2012
# 4       Observation of a new particle in the search fo...  2012
# ...                                                   ...   ...
# 148589  NIH consensus definition and classification of...  1999
# 148590  The effects of clozapine, risperidone, and ola...  1999
# 148591  Effect of testosterone and estradiol in a man ...  1997
# 148592  Relation between antioxidant enzyme gene expre...  1997
# 148593  Effect of the Antiarrhythmic Agent Moricizine ...  1992
#
#                                              Source title Volume Issue  \
# 0                               Reviews of Modern Physics     83     4
# 1       Photonic Crystals: Molding the Flow of Light (...    NaN   NaN
# 2       Physical Review D - Particles, Fields, Gravita...     86     1
# 3       Physics Letters, Section B: Nuclear, Elementar...    716     1
# 4       Physics Letters, Section B: Nuclear, Elementar...    716     1
# ...                                                   ...    ...   ...
# 148589        Journal of the American Medical Association  282.0     3
# 148590                             Schizophrenia Bulletin   25.0     2
# 148591                    New England Journal of Medicine  337.0     2
# 148592                                           Diabetes   46.0    11
# 148593                    New England Journal of Medicine  327.0     4
#
#        Art. No. Page start Page end  ...  \
# 0          1057        NaN      NaN  ...
# 1           NaN        NaN      NaN  ...
# 2        010001        NaN      NaN  ...
# 3           NaN         30       61  ...
# 4           NaN          1       29  ...
# ...         ...        ...      ...  ...
# 148589      NaN        236      237  ...
# 148590      NaN        233      255  ...
# 148591      NaN         91       95  ...
# 148592      NaN       1733     1742  ...
# 148593      NaN        227      233  ...
#
#                                              Affiliations  \
# 0       Microsoft Research, Station Q, University of C...
# 1                                                     NaN
# 2       Physics Division, Lawrence Berkeley National L...
# 3       Yerevan Physics Institute, Yerevan, Armenia; I...
# 4       School of Chemistry and Physics, University of...
# ...                                                   ...
# 148589  University of Washington, Seattle, WA, United ...
# 148590  Dept. of Psychiatry, Vanderbilt Univ. School o...
# 148591  Department of Internal Medicine, University of...
# 148592  Institute of Clinical Biochemistry, Hanover Me...
# 148593                                                NaN
#
#                                 Authors with affiliations  \
# 0       Qi, X.-L., Microsoft Research, Station Q, Univ...
# 1       Joannopoulos, J.D.; Johnson, S.G.; Winn, J.N.;...
# 2       Beringer, J., Physics Division, Lawrence Berke...
# 3       Chatrchyan, S., Yerevan Physics Institute, Yer...
# 4       Aad, G., Fakulta¨t fu¨r Mathematik und Physik,...
# ...                                                   ...
# 148589  Krieger, J.N., University of Washington, Seatt...
# 148590  Meltzer, H.Y., Dept. of Psychiatry, Vanderbilt...
# 148591  Carani, C., Department of Internal Medicine, U...
# 148592  Tiedge, M., Institute of Clinical Biochemistry...
# 148593  The Cardiac Arrhythmia Suppression Trial II In...
#
#                                                  Abstract  \
# 0       Topological insulators are new states of quant...
# 1       Since it was first published in 1995,Photonic ...
# 2       This biennial Review summarizes much of partic...
# 3       Results are presented from searches for the st...
# 4       A search for the Standard Model Higgs boson in...
# ...                                                   ...
# 148589                            [No abstract available]
# 148590  Cognitive function is markedly impaired in mos...
# 148591                            [No abstract available]
# 148592  Antioxidant enzyme expression was determined i...
# 148593  The Cardiac Arrhythmia Suppression Trial (CAST...
#
#                                           Author Keywords  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                     CMS; Higgs; Physics
# 4                                                     NaN
# ...                                                   ...
# 148589                                                NaN
# 148590  Clozapine; Cognition; Neuroleptics; Olanzapine...
# 148591                                                NaN
# 148592                                                NaN
# 148593                                                NaN
#
#                                            Index Keywords Document Type  \
# 0       Band theory; Bi-Sb alloys; Field theory; Insul...       Article
# 1                                                     NaN          Book
# 2                                                     NaN       Article
# 3                                                     NaN       Article
# 4                                                     NaN       Article
# ...                                                   ...           ...
# 148589  chronic prostatitis; clinical feature; clinica...        Letter
# 148590  4 aminobutyric acid; acetylcholine; amperozide...        Review
# 148591  estradiol; adult; arthralgia; article; case re...       Article
# 148592  antioxidant; catalase; glutathione peroxidase;...       Article
# 148593  antiarrhythmic agent; beta adrenergic receptor...       Article
#
#        Publication Stage Open Access  Source                 EID
# 0                  Final         NaN  Scopus  2-s2.0-80054934761
# 1                  Final         NaN  Scopus  2-s2.0-84884088516
# 2                  Final         NaN  Scopus  2-s2.0-84969150627
# 3                  Final         NaN  Scopus  2-s2.0-84865786005
# 4                  Final         NaN  Scopus  2-s2.0-85038109506
# ...                  ...         ...     ...                 ...
# 148589             Final         NaN  Scopus   2-s2.0-0033591899
# 148590             Final         NaN  Scopus   2-s2.0-0032977410
# 148591             Final         NaN  Scopus   2-s2.0-0030797569
# 148592             Final         NaN  Scopus   2-s2.0-0030689041
# 148593             Final         NaN  Scopus   2-s2.0-0026752875
#
# [148594 rows x 24 columns]

# %%
# try again
import os
import pandas as pd

path = "/content/drive/MyDrive/"
files = [file for file in os.listdir(path) if file.endswith(".csv")]

all_table = pd.DataFrame(columns =['Title','Abstract','Index Keywords','Research Field'])

for file in files:
    #try to assign research field name
    research_field = file.rsplit("_", maxsplit=1)[0]
    all_data = pd.read_csv(os.path.join(path, file))
    all_data = all_data.filter(['Index Keywords', 'Title', 'Abstract'])
    all_data['Research Field'] = research_field
    all_table = pd.concat([all_table, all_data])
    #print(research_field)

# %%
sample_stuff = all_table.sample(frac = 1)
sample_stuff.head(10)
# Out:
#                                                   Title  \
# 365   Mitochondrial pseudogenes: Evolution's misplac...
# 78       The role of honey in the management of wounds.
# 313   Low-voltage ride-through of a full converter w...
# 658   Mood disorders in children and adolescents: An...
# 423   Multiagent systems: a survey from a machine le...
# 1180              Nonparametric instrumental regression
# 624   Synaptic mechanisms and network dynamics under...
# 913   Chromatin accessibility pre-determines glucoco...
# 657   A feasibility study of a solar desiccant air-c...
# 728   Corticocortical connections of visual, sensori...
#
#                                                Abstract  \
# 365   Nuclear copies of mitochondrial DNA (mtDNA) ha...
# 78                              [No abstract available]
# 313   The low-voltage ride-through capability of a 2...
# 658   Epidemiologic studies show that major depressi...
# 423   Distributed Artificial Intelligence (DAI) has ...
# 1180  The focus of this paper is the nonparametric e...
# 624   Single-neuron recordings from behaving primate...
# 913   Development, differentiation and response to e...
# 657   A desiccant dehumidifier in conjunction with e...
# 728   We studied the corticocortical connections of ...
#
#                                          Index Keywords Research Field
# 365   mitochondrial DNA; evolution; DNA sequence; ge...           AGRI
# 78    bandage; evidence based medicine; honey; human...           NURS
# 313   Electric generators; Permanent magnets; Synchr...           ENER
# 658   adolescence; adolescent pregnancy; adult; affe...           NEUR
# 423   Artificial intelligence; Human computer intera...           COMP
# 1180                                                NaN           ECON
# 624   n methyl dextro aspartic acid receptor; articl...           NEUR
# 913   deoxyribonuclease I; dexamethasone; glucocorti...           BIOC
# 657   Air conditioning; Computer simulation; Evapora...           ENER
# 728   animal cell; animal tissue; article; controlle...           NEUR

# %%
#split test and train datasets

train_set, test_set = train_test_split(all_table, train_size = 0.95, test_size = 0.05)
