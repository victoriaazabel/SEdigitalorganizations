# %% [markdown]
# Our first exercise dealt with a machine learning system that categorized tweets aimed at Virgin Airlines into positve, neutral, or negative. In order to practice wit this, I am going to start use the same system, Cohere, to analyze and evaluate movie reviews and assign them with the values "positive" or "negative". QUESTION: why does the identify_sentiment code only work when I'm using the api key string for cohere and not the drive.mount?

# %%
from google.colab import drive
"""
drive.mount('/content/drive')
COHERE_API_FILE = "/content/drive/MyDrive/SEDataScience/IMDB_Dataset.csv"

with open(COHERE_API_FILE, 'r') as file:
    apikey_cohere = file.read()
"""
apikey_cohere = '6dRSiFB4geEjmm8nrIDwqo1w8DgwfdSLmW3XkeFz'

# %% [markdown]
# After connecting this notebook to the Google Drive folder and accessing the document "IMDB_Dataset.csv", Co:Here needs to be installed as our machine learning model in order to teach the system whether a review is positive or negative.
# Model is set to 'xlarge' so that it can handle large amounts of data.
# The input for prompt shows what our prompt is made up of, that being the promt itself, text, and n\ meaning that it will end in a new line.
# The max_tokens set to 3 means that the output will be able to consist of one work or more as the tokens are equivalent to chars.
# A temperature of 0.5 controls the randomness of the output.
# Our stop_sequence being "---" means that the model will stop at our give end.

# %%
# !pip install cohere
import cohere

"""def cohere_text(prompt: str, tokens: int) -> str:
  co = cohere.Client(apikey_cohere)

  response = co.generate(  
    model = 'xlarge',  
    prompt = prompt + text + '\n',
    max_tokens = 3,
    temperature = 0.5,  
    stop_sequences = ["---"])
  

  return response.generations[0].text
  """
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# 'def cohere_text(prompt: str, tokens: int) -> str:\n  co = cohere.Client(apikey_cohere)\n\n  response = co.generate(  \n    model = \'xlarge\',  \n    prompt = prompt + text + \'\n\',\n    max_tokens = 3,\n    temperature = 0.5,  \n    stop_sequences = ["---"])\n  \n\n  return response.generations[0].text\n  '

# %%
import pandas as pd
REVIEWS_FILE = "/content/drive/MyDrive/SEDataScience/IMDB_Dataset.csv"

from google.colab import drive
drive.mount('/content/drive')

from google.colab import data_table
data_table.enable_dataframe_formatter()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Here, the data is being split into test and training data, allowing our model to learn first and use different parts of the dataset later for testing. In data, we are telling the model to focus on the columns Review and Sentiment. In order to differentiate between testing and training data, we give each a different subset of our data, namely the first 50 entries for training data and the last 20 for testing.

# %%
data = pd.read_csv(REVIEWS_FILE)
data = data[['review', 'sentiment']]
train = data.head(50).copy()
test = data.tail(20).copy()
test['guess'] = None
train
# Out:
#                                                review sentiment
# 0   One of the other reviewers has mentioned that ...  positive
# 1   A wonderful little production. <br /><br />The...  positive
# 2   I thought this was a wonderful way to spend ti...  positive
# 3   Basically there's a family where a little boy ...  negative
# 4   Petter Mattei's "Love in the Time of Money" is...  positive
Negative
---
The cast played Shakespeare.<br /><br />Shakespeare lost.<br /><br />I appreciate that this is trying to bring Shakespeare to the masses, but why ruin something so good.<br /><br />Is it because 'The Scottish Play' is my favorite Shakespeare? I do not know. What I do know is that a certain Rev Bowdler (hence bowdlerization) tried to do something similar in the Victorian era.<br /><br />In other words, you cannot improve perfection.<br /><br />I have no more to write but as I have to write at least ten lines of text (and English composition was never my forte I will just have to keep going and say that this movie, as the saying goes, just does not cut it.
Negative
---
Phil the Alien is one of those quirky films where the humour is based around the oddness of everything rather than actual punchlines.<br /><br />At first it was very odd and pretty funny but as the movie progressed I didn't find the jokes or oddness funny anymore.<br /><br />Its a low budget film (thats never a problem in itself), there were some pretty interesting characters, but eventually I just lost interest.<br /><br />I imagine this film would appeal to a stoner who is currently partaking.<br /><br />For something similar but better try "Brother from another planet"
Negative
---
"""

  response = co.generate(  
    model = 'xlarge',  
    prompt = prompt + text + '\n',
    max_tokens = 3,
    temperature = 0.5,  
    stop_sequences = ["---"])
  
  return response.generations[0].text.replace("\n", "").replace("---", "")

identify_sentiment("The cast played Shakespeare.<br /><br />Shakespeare lost.<br /><br />I appreciate that this is trying to bring Shakespeare to the masses, but why ruin something so good.<br /><br />Is it because 'The Scottish Play' is my favorite Shakespeare? I do not know. What I do know is that a certain Rev Bowdler (hence bowdlerization) tried to do something similar in the Victorian era.<br /><br />In other words, you cannot improve perfection.<br /><br />I have no more to write but as I have to write at least ten lines of text (and English composition was never my forte I will just have to keep going and say that this movie, as the saying goes, just does not cut it.")
# Out:
# 'Negative'

# %% [markdown]
# The following code is being used to analzye our dataset using the preciously defined function "identify_sentiment" as welll as calculating the percentage of guesses that were correct in the model, a higher number (closer to 1.0) is preferred.

# %%
import time

for id, text in enumerate(test['review']):
  while True:
        try:
          guess = identify_sentiment(review)
          test.iloc[id, 2] = guess
          time.sleep(0.05)
        except:
            time.sleep(0.2)
            continue
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-22e4d428c30e> in <module>
#       5         try:
# ----> 6           guess = identify_sentiment(review)
#       7           test.iloc[id, 2] = guess
#
# NameError: name 'review' is not defined
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-22e4d428c30e> in <module>
#       8           time.sleep(0.05)
#       9         except:
# ---> 10             time.sleep(0.2)
#      11             continue
#      12         break
#
# KeyboardInterrupt:

# %%
test['correct'] = test['sentiment'] == test['guess']
print("Percentage of correct sentiments:")
test['correct'].value_counts()[True]/len(test['correct'])
# Out:
# Percentage of correct sentiments:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# In addition to the exercise above, I played with an idea provided at the end of the exercise, namely "Use OpenAi's GPT-3 API and try to systematically analyze a dataset using an NLP task of your choice" with the NLP task being "headline generation.
